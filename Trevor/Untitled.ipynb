# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
file1 = "mass_shooting_2019.csv"
file2 = "mass_shooting_2020.csv"
file3 = "mass_shooting_2021.csv"

# %%
df_2019 = pd.read_csv(file1)
df_2020 = pd.read_csv(file2)
df_2021 = pd.read_csv(file3)

# %%
df_2019
# Out:
#      Incident ID      Incident Date           State City Or County  \
# 0        1582816  December 29, 2019        Illinois       Danville
# 1        1582197  December 29, 2019        New York        Buffalo
# 2        1583444  December 29, 2019      California          Ceres
# 3        1581590  December 27, 2019      California        Modesto
# 4        1581103  December 27, 2019           Texas        Houston
# ..           ...                ...             ...            ...
# 412      1293054    January 4, 2019      California       Torrance
# 413      1292941    January 3, 2019         Arizona           Yuma
# 414      1291779    January 2, 2019        Arkansas      Jonesboro
# 415      1289877    January 1, 2019  South Carolina       Columbia
# 416      1289618    January 1, 2019         Florida    Tallahassee
#
#                            Address  # Killed  # Injured  Operations
# 0       1803 block of Westview Ave         0          5         NaN
# 1        50 block of Henrietta Ave         1          3         NaN
# 2        800 block of Allacante Dr         0          5         NaN
# 3         1900 block of Vernon Ave         1          3         NaN
# 4            500 block of Smart St         2          7         NaN
# ..                             ...       ...        ...         ...
# 412           22501 Hawthorne Blvd         3          4         NaN
# 413  3800 block of E County 18½ St         1          3         NaN
# 414                 3516 Galaxy St         1          3         NaN
# 415               1709 Decker Blvd         0          5         NaN
# 416            2020 W Pensacola St         0          5         NaN
#
# [417 rows x 8 columns]

# %%
df_2020
# Out:
#      Incident ID      Incident Date          State City Or County  \
# 0        1891461  December 31, 2020        Indiana   Indianapolis
# 1        1890946  December 31, 2020         Oregon   Happy Valley
# 2        1886974  December 26, 2020       Illinois       Rockford
# 3        1886913  December 26, 2020        Florida          Tampa
# 4        1887059  December 26, 2020  Massachusetts           Lynn
# ..           ...                ...            ...            ...
# 606      1588308    January 4, 2020        Florida          Ocala
# 607      1586839    January 2, 2020       New York       Brooklyn
# 608      1585746    January 1, 2020           Ohio      Cleveland
# 609      1585394    January 1, 2020  West Virginia     Huntington
# 610      1585894    January 1, 2020       Missouri    Saint Louis
#
#                            Address  # Killed  # Injured  Operations
# 0             8215 Center Run Road         1          3         NaN
# 1      9200 block of SE Idleman Rd         0          4         NaN
# 2                  4007 E State St         3          3         NaN
# 3          N 20th St and E 7th Ave         2          2         NaN
# 4     Washington St and Quincy Ter         1          5         NaN
# ..                             ...       ...        ...         ...
# 606        800 block of NW 6th Ter         1          3         NaN
# 607                   6120 3rd Ave         0          4         NaN
# 608           1437 St Clair Ave NE         0          4         NaN
# 609                   1113 4th Ave         0          7         NaN
# 610  3000 block of S Jefferson Ave         3          2         NaN
#
# [611 rows x 8 columns]

# %%
df_2021
# Out:
#      Incident ID       Incident Date       State City Or County  \
# 0        2125953  September 26, 2021  California        Oakland
# 1        2125790  September 26, 2021    Illinois        Chicago
# 2        2125613  September 25, 2021    New York          Utica
# 3        2125227  September 25, 2021  California      Riverside
# 4        2125444  September 25, 2021   Tennessee         Athens
# ..           ...                 ...         ...            ...
# 518      1893744     January 3, 2021     Florida          Miami
# 519      1892114     January 1, 2021        Iowa     Sioux City
# 520      1892034     January 1, 2021    Arkansas     Fort Smith
# 521      1892704     January 1, 2021       Texas       Amarillo
# 522      1891720     January 1, 2021    Illinois      Galesburg
#
#                         Address  # Killed  # Injured  Operations
# 0         1400 block of 8th Ave         0          4         NaN
# 1     800 block of S Albany Ave         0          0         NaN
# 2        800 block of Mohawk St         0          4         NaN
# 3    6000 Block of Mariposa Ave         0          6         NaN
# 4                      Co Rd 60         4          0         NaN
# ..                          ...       ...        ...         ...
# 518           10525 NW 24th Ave         0          8         NaN
# 519            2637 S Walker St         1          4         NaN
# 520             3211 Towson Ave         0          7         NaN
# 521               2650 Dumas Dr         1          3         NaN
# 522     1000 block of Monroe St         0          4         NaN
#
# [523 rows x 8 columns]

# %%
frames = [df_2019, df_2020, df_2021]

result = pd.concat(frames)

# %%
result
# Out:
#      Incident ID      Incident Date       State City Or County  \
# 0        1582816  December 29, 2019    Illinois       Danville
# 1        1582197  December 29, 2019    New York        Buffalo
# 2        1583444  December 29, 2019  California          Ceres
# 3        1581590  December 27, 2019  California        Modesto
# 4        1581103  December 27, 2019       Texas        Houston
# ..           ...                ...         ...            ...
# 518      1893744    January 3, 2021     Florida          Miami
# 519      1892114    January 1, 2021        Iowa     Sioux City
# 520      1892034    January 1, 2021    Arkansas     Fort Smith
# 521      1892704    January 1, 2021       Texas       Amarillo
# 522      1891720    January 1, 2021    Illinois      Galesburg
#
#                         Address  # Killed  # Injured  Operations
# 0    1803 block of Westview Ave         0          5         NaN
# 1     50 block of Henrietta Ave         1          3         NaN
# 2     800 block of Allacante Dr         0          5         NaN
# 3      1900 block of Vernon Ave         1          3         NaN
# 4         500 block of Smart St         2          7         NaN
# ..                          ...       ...        ...         ...
# 518           10525 NW 24th Ave         0          8         NaN
# 519            2637 S Walker St         1          4         NaN
# 520             3211 Towson Ave         0          7         NaN
# 521               2650 Dumas Dr         1          3         NaN
# 522     1000 block of Monroe St         0          4         NaN
#
# [1551 rows x 8 columns]

# %%
result['Address'] = result['Address'].str.replace("block of", '')

# %%
result["Full_Address"] = result['Address'] + ', ' + result['City Or County'] + ' ' + result['State']

# %%
result
# Out:
#      Incident ID      Incident Date       State City Or County  \
# 0        1582816  December 29, 2019    Illinois       Danville
# 1        1582197  December 29, 2019    New York        Buffalo
# 2        1583444  December 29, 2019  California          Ceres
# 3        1581590  December 27, 2019  California        Modesto
# 4        1581103  December 27, 2019       Texas        Houston
# ..           ...                ...         ...            ...
# 518      1893744    January 3, 2021     Florida          Miami
# 519      1892114    January 1, 2021        Iowa     Sioux City
# 520      1892034    January 1, 2021    Arkansas     Fort Smith
# 521      1892704    January 1, 2021       Texas       Amarillo
# 522      1891720    January 1, 2021    Illinois      Galesburg
#
#                 Address  # Killed  # Injured  Operations  \
# 0    1803  Westview Ave         0          5         NaN
# 1     50  Henrietta Ave         1          3         NaN
# 2     800  Allacante Dr         0          5         NaN
# 3      1900  Vernon Ave         1          3         NaN
# 4         500  Smart St         2          7         NaN
# ..                  ...       ...        ...         ...
# 518   10525 NW 24th Ave         0          8         NaN
# 519    2637 S Walker St         1          4         NaN
# 520     3211 Towson Ave         0          7         NaN
# 521       2650 Dumas Dr         1          3         NaN
# 522     1000  Monroe St         0          4         NaN
#
#                               Full_Address
# 0    1803  Westview Ave, Danville Illinois
# 1      50  Henrietta Ave, Buffalo New York
# 2      800  Allacante Dr, Ceres California
# 3     1900  Vernon Ave, Modesto California
# 4             500  Smart St, Houston Texas
# ..                                     ...
# 518       10525 NW 24th Ave, Miami Florida
# 519      2637 S Walker St, Sioux City Iowa
# 520   3211 Towson Ave, Fort Smith Arkansas
# 521          2650 Dumas Dr, Amarillo Texas
# 522    1000  Monroe St, Galesburg Illinois
#
# [1551 rows x 9 columns]

# %%
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim

locator = Nominatim(user_agent="myGeocoder")

# %%
# 1 - conveneint function to delay between geocoding calls

geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
geocode = locator.geocode

# 2- - create location column
result['location'] = result['Full_Address'].apply(geocode)

# 3 - create longitude, laatitude and altitude from location column (returns tuple)
result['lat'] = result['location'].apply(lambda loc: tuple(loc.latitude) if loc else None)
result['long'] = result['location'].apply(lambda loc: tuple(loc.longitude) if loc else None)

# %%
result

# %%
result.to_csv("results_parsed_2.csv")
